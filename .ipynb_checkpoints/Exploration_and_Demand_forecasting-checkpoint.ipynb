# %%
import numpy as np
import folium
from datetime import datetime

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#        id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0  132512    22177                28         NaN               2
# 1  132513    21413                12         NaN               2
# 2  132514    22178                12         NaN               2
# 3  132515    13034                12         NaN               2
# 4  132517    22180                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id      from_date to_date  \
# 0          83.0       448.0           NaN         NaN  1/1/2013 2:00     NaN
# 1        1010.0       540.0           NaN         NaN  1/1/2013 9:00     NaN
# 2        1301.0      1034.0           NaN         NaN  1/1/2013 3:30     NaN
# 3         768.0       398.0           NaN         NaN  1/1/2013 5:45     NaN
# 4        1365.0       849.0           NaN         NaN  1/1/2013 9:00     NaN
#
#    online_booking  mobile_site_booking booking_created   from_lat  from_long  \
# 0               0                    0   1/1/2013 1:39  12.924150  77.672290
# 1               0                    0   1/1/2013 2:25  12.966910  77.749350
# 2               0                    0   1/1/2013 3:08  12.937222  77.626915
# 3               0                    0   1/1/2013 4:39  12.989990  77.553320
# 4               0                    0   1/1/2013 7:53  12.845653  77.677925
#
#       to_lat    to_long  Car_Cancellation
# 0  12.927320  77.635750                 0
# 1  12.927680  77.626640                 0
# 2  13.047926  77.597766                 0
# 3  12.971430  77.639140                 0
# 4  12.954340  77.600720                 0

# %%
df.describe()
# Out:
#                   id       user_id  vehicle_model_id   package_id  \
# count   43431.000000  43431.000000       43431.00000  7550.000000
# mean   159206.473556  30739.198153          25.71723     2.030066
# std     15442.386279  10996.476709          26.79825     1.461756
# min    132512.000000     16.000000           1.00000     1.000000
# 25%    145778.000000  24614.000000          12.00000     1.000000
# 50%    159248.000000  31627.000000          12.00000     2.000000
# 75%    172578.500000  39167.000000          24.00000     2.000000
# max    185941.000000  48730.000000          91.00000     7.000000
#
#        travel_type_id  from_area_id    to_area_id  from_city_id   to_city_id  \
# count    43431.000000  43343.000000  34293.000000  16345.000000  1588.000000
# mean         2.137252    714.544494    669.490917     14.915081    68.537783
# std          0.437712    419.883553    400.638225      1.165306    49.880732
# min          1.000000      2.000000      2.000000      1.000000     4.000000
# 25%          2.000000    393.000000    393.000000     15.000000    32.000000
# 50%          2.000000    590.000000    541.000000     15.000000    49.000000
# 75%          2.000000   1089.000000   1054.000000     15.000000   108.000000
# max          3.000000   1403.000000   1403.000000     31.000000   203.000000
#
#        online_booking  mobile_site_booking      from_lat     from_long  \
# count    43431.000000         43431.000000  43338.000000  43338.000000
# mean         0.351592             0.043241     12.982461     77.636255
# std          0.477473             0.203402      0.085933      0.059391
# min          0.000000             0.000000     12.776630     77.386930
# 25%          0.000000             0.000000     12.926450     77.593661
# 50%          0.000000             0.000000     12.968887     77.635750
# 75%          1.000000             0.000000     13.007750     77.688900
# max          1.000000             1.000000     13.366072     77.786420
#
#              to_lat       to_long  Car_Cancellation
# count  34293.000000  34293.000000      43431.000000
# mean      13.026648     77.640595          0.072114
# std        0.113487      0.064045          0.258680
# min       12.776630     77.386930          0.000000
# 25%       12.951850     77.582030          0.000000
# 50%       12.982750     77.645030          0.000000
# 75%       13.199560     77.706880          0.000000
# max       13.366072     77.786420          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43431 entries, 0 to 43430
# Data columns (total 19 columns):
# id                     43431 non-null int64
# user_id                43431 non-null int64
# vehicle_model_id       43431 non-null int64
# package_id             7550 non-null float64
# travel_type_id         43431 non-null int64
# from_area_id           43343 non-null float64
# to_area_id             34293 non-null float64
# from_city_id           16345 non-null float64
# to_city_id             1588 non-null float64
# from_date              43431 non-null object
# to_date                25541 non-null object
# online_booking         43431 non-null int64
# mobile_site_booking    43431 non-null int64
# booking_created        43431 non-null object
# from_lat               43338 non-null float64
# from_long              43338 non-null float64
# to_lat                 34293 non-null float64
# to_long                34293 non-null float64
# Car_Cancellation       43431 non-null int64
# dtypes: float64(9), int64(7), object(3)
# memory usage: 6.3+ MB

# %%
df.shape
# Out:
# (43431, 19)

# %%
# finding unique area_ids for both 'to' and 'from' i.e. pickup and drop area_ids 

no_of_from_areas = len(df['from_area_id'].unique())
no_of_to_areas = len(df['to_area_id'].unique())

# %%
no_of_from_areas
# Out:
# 599

# %%
no_of_to_areas
# Out:
# 569

# %%
areas = df['to_area_id'].tolist() + df['from_area_id'].tolist()           # merging 'to' and 'from' area_ids

# %%
len(areas)
# Out:
# 86862

# %%
clean_areas =  [area for area in areas if str(area).strip() !='nan']      # removing nans for count of total area_ids

# %%
clean_areas
# Out:
# [448.0,
#  540.0,
#  1034.0,
#  398.0,
#  849.0,
#  1323.0,
#  832.0,
#  376.0,
#  776.0,
#  1330.0,
#  1328.0,
#  590.0,
#  58.0,
#  292.0,
#  393.0,
#  585.0,
#  212.0,
#  1063.0,
#  409.0,
#  393.0,
#  61.0,
#  585.0,
#  330.0,
#  393.0,
#  1068.0,
#  1194.0,
#  1010.0,
#  839.0,
#  496.0,
#  393.0,
#  571.0,
#  1390.0,
#  1384.0,
#  1270.0,
#  585.0,
#  571.0,
#  393.0,
#  83.0,
#  1021.0,
#  793.0,
#  1075.0,
#  1010.0,
#  363.0,
#  1153.0,
#  186.0,
#  393.0,
#  393.0,
#  393.0,
#  1189.0,
#  392.0,
#  871.0,
#  1053.0,
#  1068.0,
#  393.0,
#  393.0,
#  585.0,
#  186.0,
#  949.0,
#  793.0,
#  1384.0,
#  1183.0,
#  393.0,
#  1194.0,
#  393.0,
#  217.0,
#  585.0,
#  585.0,
#  393.0,
#  393.0,
#  585.0,
#  466.0,
#  393.0,
#  393.0,
#  1223.0,
#  142.0,
#  1069.0,
#  1384.0,
#  409.0,
#  763.0,
#  393.0,
#  1056.0,
#  585.0,
#  776.0,
#  142.0,
#  168.0,
#  105.0,
#  448.0,
#  393.0,
#  1084.0,
#  1084.0,
#  112.0,
#  112.0,
#  393.0,
#  393.0,
#  393.0,
#  793.0,
#  393.0,
#  1384.0,
#  58.0,
#  1237.0,
#  571.0,
#  393.0,
#  292.0,
#  393.0,
#  167.0,
#  297.0,
#  393.0,
#  171.0,
#  410.0,
#  793.0,
#  458.0,
#  393.0,
#  1312.0,
#  297.0,
#  136.0,
#  1026.0,
#  450.0,
#  393.0,
#  393.0,
#  1038.0,
#  478.0,
#  1166.0,
#  585.0,
#  968.0,
#  1341.0,
#  1044.0,
#  112.0,
#  271.0,
#  1384.0,
#  156.0,
#  1010.0,
#  1191.0,
#  393.0,
#  393.0,
#  793.0,
#  1021.0,
#  585.0,
#  585.0,
#  1384.0,
#  393.0,
#  585.0,
#  585.0,
#  243.0,
#  585.0,
#  572.0,
#  585.0,
#  393.0,
#  171.0,
#  393.0,
#  393.0,
#  393.0,
#  1390.0,
#  393.0,
#  689.0,
#  1046.0,
#  1384.0,
#  793.0,
#  393.0,
#  186.0,
#  585.0,
#  767.0,
#  393.0,
#  176.0,
#  220.0,
#  1086.0,
#  393.0,
#  410.0,
#  1166.0,
#  393.0,
#  218.0,
#  1038.0,
#  1372.0,
#  708.0,
#  1084.0,
#  1261.0,
#  1068.0,
#  156.0,
#  393.0,
#  393.0,
#  393.0,
#  1384.0,
#  393.0,
#  393.0,
#  58.0,
#  601.0,
#  393.0,
#  391.0,
#  603.0,
#  1384.0,
#  458.0,
#  1181.0,
#  83.0,
#  1096.0,
#  585.0,
#  393.0,
#  393.0,
#  393.0,
#  1017.0,
#  1136.0,
#  1374.0,
#  484.0,
#  344.0,
#  1333.0,
#  730.0,
#  776.0,
#  92.0,
#  171.0,
#  585.0,
#  1298.0,
#  297.0,
#  1371.0,
#  1384.0,
#  667.0,
#  585.0,
#  1085.0,
#  455.0,
#  572.0,
#  393.0,
#  849.0,
#  168.0,
#  393.0,
#  136.0,
#  1078.0,
#  455.0,
#  410.0,
#  393.0,
#  1217.0,
#  136.0,
#  393.0,
#  296.0,
#  393.0,
#  393.0,
#  1373.0,
#  393.0,
#  393.0,
#  393.0,
#  168.0,
#  1038.0,
#  1371.0,
#  1021.0,
#  218.0,
#  601.0,
#  353.0,
#  1033.0,
#  1021.0,
#  767.0,
#  1166.0,
#  393.0,
#  1074.0,
#  484.0,
#  171.0,
#  149.0,
#  1230.0,
#  839.0,
#  418.0,
#  1089.0,
#  1089.0,
#  122.0,
#  393.0,
#  83.0,
#  393.0,
#  1017.0,
#  1021.0,
#  571.0,
#  186.0,
#  585.0,
#  767.0,
#  767.0,
#  168.0,
#  625.0,
#  585.0,
#  393.0,
#  363.0,
#  570.0,
#  393.0,
#  1062.0,
#  750.0,
#  393.0,
#  149.0,
#  601.0,
#  515.0,
#  1257.0,
#  667.0,
#  1384.0,
#  784.0,
#  393.0,
#  987.0,
#  567.0,
#  1383.0,
#  393.0,
#  567.0,
#  271.0,
#  271.0,
#  1390.0,
#  455.0,
#  393.0,
#  1371.0,
#  571.0,
#  1021.0,
#  393.0,
#  1349.0,
#  571.0,
#  393.0,
#  585.0,
#  1330.0,
#  458.0,
#  1301.0,
#  571.0,
#  852.0,
#  1388.0,
#  603.0,
#  393.0,
#  83.0,
#  83.0,
#  1010.0,
#  784.0,
#  398.0,
#  1059.0,
#  393.0,
#  393.0,
#  393.0,
#  994.0,
#  1349.0,
#  542.0,
#  542.0,
#  393.0,
#  1096.0,
#  1384.0,
#  393.0,
#  1084.0,
#  1384.0,
#  136.0,
#  393.0,
#  1384.0,
#  484.0,
#  293.0,
#  1165.0,
#  1237.0,
#  1194.0,
#  585.0,
#  393.0,
#  293.0,
#  112.0,
#  793.0,
#  393.0,
#  585.0,
#  571.0,
#  585.0,
#  214.0,
#  455.0,
#  1192.0,
#  585.0,
#  393.0,
#  393.0,
#  393.0,
#  776.0,
#  708.0,
#  776.0,
#  1052.0,
#  1021.0,
#  949.0,
#  1021.0,
#  625.0,
#  1068.0,
#  601.0,
#  601.0,
#  1095.0,
#  1189.0,
#  585.0,
#  974.0,
#  58.0,
#  1046.0,
#  515.0,
#  1384.0,
#  393.0,
#  1068.0,
#  363.0,
#  393.0,
#  393.0,
#  1384.0,
#  585.0,
#  393.0,
#  585.0,
#  393.0,
#  393.0,
#  571.0,
#  393.0,
#  357.0,
#  681.0,
#  873.0,
#  1334.0,
#  1334.0,
#  168.0,
#  392.0,
#  1389.0,
#  1021.0,
#  393.0,
#  1283.0,
#  393.0,
#  393.0,
#  1096.0,
#  393.0,
#  393.0,
#  585.0,
#  393.0,
#  1096.0,
#  1017.0,
#  156.0,
#  393.0,
#  1323.0,
#  529.0,
#  393.0,
#  393.0,
#  585.0,
#  585.0,
#  393.0,
#  25.0,
#  83.0,
#  393.0,
#  393.0,
#  758.0,
#  1096.0,
#  585.0,
#  1084.0,
#  393.0,
#  585.0,
#  852.0,
#  1059.0,
#  571.0,
#  1059.0,
#  572.0,
#  1068.0,
#  463.0,
#  1244.0,
#  1165.0,
#  393.0,
#  393.0,
#  585.0,
#  572.0,
#  1260.0,
#  1262.0,
#  1261.0,
#  768.0,
#  1108.0,
#  1384.0,
#  471.0,
#  1328.0,
#  1192.0,
#  1068.0,
#  393.0,
#  585.0,
#  393.0,
#  455.0,
#  455.0,
#  393.0,
#  1384.0,
#  814.0,
#  83.0,
#  1021.0,
#  58.0,
#  1234.0,
#  1026.0,
#  1017.0,
#  115.0,
#  25.0,
#  393.0,
#  393.0,
#  1086.0,
#  393.0,
#  450.0,
#  1294.0,
#  793.0,
#  393.0,
#  186.0,
#  58.0,
#  219.0,
#  849.0,
#  393.0,
#  625.0,
#  393.0,
#  393.0,
#  334.0,
#  585.0,
#  450.0,
#  156.0,
#  793.0,
#  1175.0,
#  1337.0,
#  83.0,
#  393.0,
#  184.0,
#  393.0,
#  463.0,
#  308.0,
#  1021.0,
#  197.0,
#  1079.0,
#  393.0,
#  1053.0,
#  1037.0,
#  1083.0,
#  585.0,
#  393.0,
#  393.0,
#  393.0,
#  1154.0,
#  488.0,
#  393.0,
#  418.0,
#  393.0,
#  1056.0,
#  83.0,
#  393.0,
#  1147.0,
#  1234.0,
#  393.0,
#  393.0,
#  1068.0,
#  1096.0,
#  580.0,
#  85.0,
#  271.0,
#  358.0,
#  393.0,
#  105.0,
#  571.0,
#  293.0,
#  393.0,
#  393.0,
#  585.0,
#  1084.0,
#  393.0,
#  393.0,
#  1261.0,
#  776.0,
#  529.0,
#  393.0,
#  58.0,
#  1021.0,
#  452.0,
#  585.0,
#  677.0,
#  1383.0,
#  393.0,
#  393.0,
#  393.0,
#  1279.0,
#  1328.0,
#  393.0,
#  572.0,
#  1244.0,
#  393.0,
#  220.0,
#  455.0,
#  393.0,
#  585.0,
#  1170.0,
#  393.0,
#  330.0,
#  691.0,
#  849.0,
#  330.0,
#  585.0,
#  1330.0,
#  571.0,
#  393.0,
#  1340.0,
#  149.0,
#  393.0,
#  393.0,
#  1388.0,
#  353.0,
#  585.0,
#  1234.0,
#  393.0,
#  393.0,
#  83.0,
#  625.0,
#  393.0,
#  832.0,
#  83.0,
#  171.0,
#  334.0,
#  585.0,
#  1068.0,
#  585.0,
#  271.0,
#  793.0,
#  393.0,
#  168.0,
#  393.0,
#  105.0,
#  393.0,
#  393.0,
#  585.0,
#  1373.0,
#  708.0,
#  393.0,
#  25.0,
#  448.0,
#  393.0,
#  393.0,
#  1017.0,
#  585.0,
#  393.0,
#  949.0,
#  572.0,
#  393.0,
#  1166.0,
#  1314.0,
#  871.0,
#  393.0,
#  393.0,
#  1384.0,
#  393.0,
#  451.0,
#  393.0,
#  393.0,
#  393.0,
#  793.0,
#  393.0,
#  1244.0,
#  393.0,
#  83.0,
#  455.0,
#  571.0,
#  293.0,
#  393.0,
#  722.0,
#  849.0,
#  393.0,
#  585.0,
#  393.0,
#  393.0,
#  585.0,
#  571.0,
#  949.0,
#  585.0,
#  393.0,
#  1389.0,
#  393.0,
#  393.0,
#  585.0,
#  83.0,
#  1373.0,
#  393.0,
#  585.0,
#  393.0,
#  393.0,
#  1186.0,
#  451.0,
#  1328.0,
#  393.0,
#  1234.0,
#  540.0,
#  1102.0,
#  585.0,
#  393.0,
#  168.0,
#  271.0,
#  836.0,
#  1384.0,
#  393.0,
#  1038.0,
#  1096.0,
#  393.0,
#  393.0,
#  413.0,
#  393.0,
#  58.0,
#  1068.0,
#  393.0,
#  585.0,
#  51.0,
#  393.0,
#  393.0,
#  238.0,
#  1384.0,
#  452.0,
#  767.0,
#  667.0,
#  585.0,
#  484.0,
#  393.0,
#  1102.0,
#  393.0,
#  393.0,
#  393.0,
#  393.0,
#  58.0,
#  393.0,
#  1166.0,
#  1384.0,
#  1371.0,
#  585.0,
#  393.0,
#  625.0,
#  1057.0,
#  136.0,
#  393.0,
#  105.0,
#  585.0,
#  136.0,
#  182.0,
#  452.0,
#  455.0,
#  293.0,
#  585.0,
#  393.0,
#  1133.0,
#  25.0,
#  1161.0,
#  571.0,
#  393.0,
#  1192.0,
#  393.0,
#  25.0,
#  1053.0,
#  149.0,
#  1281.0,
#  393.0,
#  393.0,
#  1010.0,
#  393.0,
#  105.0,
#  572.0,
#  1021.0,
#  1038.0,
#  585.0,
#  934.0,
#  1384.0,
#  393.0,
#  452.0,
#  1189.0,
#  409.0,
#  529.0,
#  1038.0,
#  1333.0,
#  1191.0,
#  585.0,
#  404.0,
#  393.0,
#  393.0,
#  692.0,
#  585.0,
#  393.0,
#  763.0,
#  393.0,
#  1084.0,
#  393.0,
#  1045.0,
#  1017.0,
#  218.0,
#  182.0,
#  1154.0,
#  136.0,
#  142.0,
#  393.0,
#  432.0,
#  393.0,
#  585.0,
#  1142.0,
#  1147.0,
#  393.0,
#  393.0,
#  112.0,
#  393.0,
#  393.0,
#  1054.0,
#  393.0,
#  515.0,
#  585.0,
#  1154.0,
#  1154.0,
#  571.0,
#  585.0,
#  293.0,
#  330.0,
#  585.0,
#  1033.0,
#  451.0,
#  559.0,
#  559.0,
#  776.0,
#  1262.0,
#  393.0,
#  988.0,
#  393.0,
#  1230.0,
#  1384.0,
#  293.0,
#  58.0,
#  1021.0,
#  571.0,
#  1147.0,
#  1239.0,
#  484.0,
#  1017.0,
#  1087.0,
#  393.0,
#  683.0,
#  393.0,
#  484.0,
#  1169.0,
#  458.0,
#  142.0,
#  393.0,
#  344.0,
#  393.0,
#  1010.0,
#  1096.0,
#  1234.0,
#  149.0,
#  393.0,
#  1063.0,
#  156.0,
#  1192.0,
#  1166.0,
#  393.0,
#  393.0,
#  393.0,
#  330.0,
#  585.0,
#  988.0,
#  988.0,
#  393.0,
#  585.0,
#  689.0,
#  393.0,
#  455.0,
#  1323.0,
#  1205.0,
#  1384.0,
#  393.0,
#  392.0,
#  393.0,
#  344.0,
#  393.0,
#  585.0,
#  1282.0,
#  393.0,
#  1189.0,
#  1205.0,
#  1111.0,
#  214.0,
#  393.0,
#  1338.0,
#  451.0,
#  722.0,
#  1237.0,
#  1322.0,
#  832.0,
#  393.0,
#  393.0,
#  85.0,
#  393.0,
#  393.0,
#  1192.0,
#  1056.0,
#  393.0,
#  767.0,
#  463.0,
#  1264.0,
#  471.0,
#  585.0,
#  393.0,
#  393.0,
#  293.0,
#  1032.0,
#  1281.0,
#  784.0,
#  1021.0,
#  393.0,
#  293.0,
#  393.0,
#  1053.0,
#  1384.0,
#  190.0,
#  393.0,
#  393.0,
#  1166.0,
#  293.0,
#  393.0,
#  1191.0,
#  393.0,
#  117.0,
#  243.0,
#  571.0,
#  1026.0,
#  455.0,
#  451.0,
#  1056.0,
#  1257.0,
#  393.0,
#  393.0,
#  142.0,
#  945.0,
#  393.0,
#  1070.0,
#  499.0,
#  571.0,
#  271.0,
#  393.0,
#  995.0,
#  492.0,
#  1264.0,
#  1384.0,
#  585.0,
#  393.0,
#  571.0,
#  393.0,
#  393.0,
#  117.0,
#  585.0,
#  293.0,
#  393.0,
#  585.0,
#  585.0,
#  393.0,
#  393.0,
#  97.0,
#  393.0,
#  1384.0,
#  393.0,
#  293.0,
#  585.0,
#  393.0,
#  625.0,
#  1250.0,
#  450.0,
#  1021.0,
#  393.0,
#  585.0,
#  308.0,
#  1365.0,
#  393.0,
#  953.0,
#  1068.0,
#  1384.0,
#  451.0,
#  572.0,
#  492.0,
#  1330.0,
#  1328.0,
#  1354.0,
#  450.0,
#  1365.0,
#  393.0,
#  171.0,
#  393.0,
#  238.0,
#  571.0,
#  393.0,
#  463.0,
#  393.0,
#  784.0,
#  97.0,
#  1390.0,
#  1328.0,
#  499.0,
#  1010.0,
#  393.0,
#  61.0,
#  58.0,
#  186.0,
#  1075.0,
#  1010.0,
#  393.0,
#  209.0,
#  392.0,
#  1384.0,
#  49.0,
#  362.0,
#  393.0,
#  1010.0,
#  186.0,
#  590.0,
#  484.0,
#  393.0,
#  353.0,
#  585.0,
#  585.0,
#  1384.0,
#  393.0,
#  1323.0,
#  393.0,
#  1021.0,
#  1021.0,
#  571.0,
#  1102.0,
#  115.0,
#  186.0,
#  393.0,
#  1142.0,
#  168.0,
#  243.0,
#  393.0,
#  1282.0,
#  393.0,
#  1021.0,
#  ...]

# %%
# these area_ids will be useful while forecasting the demand area_wise

area_ids = set(clean_areas)

# %%
len(area_ids)
# Out:
# 607

# %%
list(area_ids)
# Out:
# [2.0,
#  6.0,
#  15.0,
#  16.0,
#  17.0,
#  22.0,
#  24.0,
#  25.0,
#  34.0,
#  49.0,
#  50.0,
#  51.0,
#  52.0,
#  58.0,
#  61.0,
#  62.0,
#  67.0,
#  68.0,
#  72.0,
#  79.0,
#  83.0,
#  85.0,
#  87.0,
#  89.0,
#  91.0,
#  92.0,
#  95.0,
#  97.0,
#  104.0,
#  105.0,
#  112.0,
#  115.0,
#  117.0,
#  118.0,
#  119.0,
#  120.0,
#  122.0,
#  128.0,
#  130.0,
#  133.0,
#  136.0,
#  137.0,
#  138.0,
#  141.0,
#  142.0,
#  143.0,
#  145.0,
#  147.0,
#  149.0,
#  150.0,
#  151.0,
#  156.0,
#  157.0,
#  160.0,
#  167.0,
#  168.0,
#  171.0,
#  172.0,
#  173.0,
#  174.0,
#  176.0,
#  177.0,
#  178.0,
#  181.0,
#  182.0,
#  184.0,
#  185.0,
#  186.0,
#  187.0,
#  190.0,
#  192.0,
#  195.0,
#  197.0,
#  200.0,
#  201.0,
#  203.0,
#  206.0,
#  207.0,
#  209.0,
#  211.0,
#  212.0,
#  213.0,
#  214.0,
#  215.0,
#  216.0,
#  217.0,
#  218.0,
#  219.0,
#  220.0,
#  221.0,
#  222.0,
#  227.0,
#  235.0,
#  238.0,
#  243.0,
#  253.0,
#  262.0,
#  264.0,
#  269.0,
#  271.0,
#  273.0,
#  278.0,
#  292.0,
#  293.0,
#  296.0,
#  297.0,
#  300.0,
#  301.0,
#  308.0,
#  321.0,
#  326.0,
#  328.0,
#  330.0,
#  334.0,
#  339.0,
#  344.0,
#  352.0,
#  353.0,
#  355.0,
#  356.0,
#  357.0,
#  358.0,
#  362.0,
#  363.0,
#  367.0,
#  369.0,
#  373.0,
#  376.0,
#  384.0,
#  391.0,
#  392.0,
#  393.0,
#  396.0,
#  398.0,
#  404.0,
#  409.0,
#  410.0,
#  413.0,
#  414.0,
#  417.0,
#  418.0,
#  419.0,
#  420.0,
#  422.0,
#  424.0,
#  428.0,
#  432.0,
#  433.0,
#  447.0,
#  448.0,
#  450.0,
#  451.0,
#  452.0,
#  455.0,
#  458.0,
#  463.0,
#  466.0,
#  467.0,
#  471.0,
#  478.0,
#  479.0,
#  483.0,
#  484.0,
#  488.0,
#  492.0,
#  496.0,
#  499.0,
#  502.0,
#  505.0,
#  515.0,
#  516.0,
#  520.0,
#  525.0,
#  529.0,
#  531.0,
#  540.0,
#  541.0,
#  542.0,
#  548.0,
#  549.0,
#  559.0,
#  561.0,
#  567.0,
#  570.0,
#  571.0,
#  572.0,
#  575.0,
#  580.0,
#  585.0,
#  590.0,
#  592.0,
#  595.0,
#  598.0,
#  601.0,
#  603.0,
#  609.0,
#  611.0,
#  625.0,
#  626.0,
#  630.0,
#  637.0,
#  644.0,
#  647.0,
#  663.0,
#  667.0,
#  677.0,
#  679.0,
#  681.0,
#  683.0,
#  689.0,
#  691.0,
#  692.0,
#  693.0,
#  708.0,
#  722.0,
#  726.0,
#  727.0,
#  730.0,
#  731.0,
#  733.0,
#  750.0,
#  758.0,
#  763.0,
#  766.0,
#  767.0,
#  768.0,
#  770.0,
#  776.0,
#  784.0,
#  788.0,
#  789.0,
#  791.0,
#  793.0,
#  798.0,
#  802.0,
#  807.0,
#  814.0,
#  817.0,
#  822.0,
#  824.0,
#  830.0,
#  832.0,
#  833.0,
#  836.0,
#  839.0,
#  845.0,
#  846.0,
#  849.0,
#  852.0,
#  869.0,
#  871.0,
#  873.0,
#  877.0,
#  888.0,
#  901.0,
#  902.0,
#  905.0,
#  912.0,
#  921.0,
#  934.0,
#  936.0,
#  945.0,
#  949.0,
#  953.0,
#  963.0,
#  968.0,
#  974.0,
#  977.0,
#  980.0,
#  987.0,
#  988.0,
#  990.0,
#  994.0,
#  995.0,
#  1004.0,
#  1005.0,
#  1008.0,
#  1010.0,
#  1012.0,
#  1013.0,
#  1014.0,
#  1015.0,
#  1017.0,
#  1021.0,
#  1025.0,
#  1026.0,
#  1032.0,
#  1033.0,
#  1034.0,
#  1036.0,
#  1037.0,
#  1038.0,
#  1039.0,
#  1040.0,
#  1041.0,
#  1042.0,
#  1043.0,
#  1044.0,
#  1045.0,
#  1046.0,
#  1049.0,
#  1052.0,
#  1053.0,
#  1054.0,
#  1056.0,
#  1057.0,
#  1058.0,
#  1059.0,
#  1060.0,
#  1061.0,
#  1062.0,
#  1063.0,
#  1064.0,
#  1065.0,
#  1066.0,
#  1067.0,
#  1068.0,
#  1069.0,
#  1070.0,
#  1071.0,
#  1072.0,
#  1074.0,
#  1075.0,
#  1076.0,
#  1077.0,
#  1078.0,
#  1079.0,
#  1080.0,
#  1081.0,
#  1082.0,
#  1083.0,
#  1084.0,
#  1085.0,
#  1086.0,
#  1087.0,
#  1089.0,
#  1090.0,
#  1091.0,
#  1092.0,
#  1094.0,
#  1095.0,
#  1096.0,
#  1097.0,
#  1098.0,
#  1099.0,
#  1100.0,
#  1101.0,
#  1102.0,
#  1103.0,
#  1106.0,
#  1107.0,
#  1108.0,
#  1109.0,
#  1110.0,
#  1111.0,
#  1112.0,
#  1113.0,
#  1114.0,
#  1117.0,
#  1118.0,
#  1119.0,
#  1120.0,
#  1121.0,
#  1122.0,
#  1123.0,
#  1124.0,
#  1125.0,
#  1126.0,
#  1127.0,
#  1129.0,
#  1130.0,
#  1133.0,
#  1135.0,
#  1136.0,
#  1141.0,
#  1142.0,
#  1143.0,
#  1145.0,
#  1147.0,
#  1148.0,
#  1149.0,
#  1150.0,
#  1152.0,
#  1153.0,
#  1154.0,
#  1155.0,
#  1156.0,
#  1157.0,
#  1158.0,
#  1159.0,
#  1160.0,
#  1161.0,
#  1163.0,
#  1164.0,
#  1165.0,
#  1166.0,
#  1167.0,
#  1168.0,
#  1169.0,
#  1170.0,
#  1171.0,
#  1173.0,
#  1174.0,
#  1175.0,
#  1178.0,
#  1180.0,
#  1181.0,
#  1182.0,
#  1183.0,
#  1184.0,
#  1185.0,
#  1186.0,
#  1189.0,
#  1190.0,
#  1191.0,
#  1192.0,
#  1193.0,
#  1194.0,
#  1195.0,
#  1196.0,
#  1197.0,
#  1198.0,
#  1199.0,
#  1200.0,
#  1201.0,
#  1204.0,
#  1205.0,
#  1206.0,
#  1207.0,
#  1208.0,
#  1209.0,
#  1213.0,
#  1214.0,
#  1215.0,
#  1216.0,
#  1217.0,
#  1218.0,
#  1220.0,
#  1222.0,
#  1223.0,
#  1224.0,
#  1225.0,
#  1226.0,
#  1228.0,
#  1229.0,
#  1230.0,
#  1232.0,
#  1233.0,
#  1234.0,
#  1235.0,
#  1237.0,
#  1238.0,
#  1239.0,
#  1240.0,
#  1242.0,
#  1243.0,
#  1244.0,
#  1245.0,
#  1246.0,
#  1247.0,
#  1248.0,
#  1249.0,
#  1250.0,
#  1252.0,
#  1253.0,
#  1254.0,
#  1255.0,
#  1257.0,
#  1258.0,
#  1259.0,
#  1260.0,
#  1261.0,
#  1262.0,
#  1263.0,
#  1264.0,
#  1265.0,
#  1266.0,
#  1267.0,
#  1268.0,
#  1269.0,
#  1270.0,
#  1271.0,
#  1272.0,
#  1273.0,
#  1274.0,
#  1275.0,
#  1276.0,
#  1277.0,
#  1278.0,
#  1279.0,
#  1280.0,
#  1281.0,
#  1282.0,
#  1283.0,
#  1284.0,
#  1285.0,
#  1286.0,
#  1287.0,
#  1288.0,
#  1289.0,
#  1290.0,
#  1291.0,
#  1292.0,
#  1293.0,
#  1294.0,
#  1295.0,
#  1296.0,
#  1297.0,
#  1298.0,
#  1299.0,
#  1300.0,
#  1301.0,
#  1302.0,
#  1303.0,
#  1304.0,
#  1305.0,
#  1306.0,
#  1307.0,
#  1308.0,
#  1309.0,
#  1310.0,
#  1311.0,
#  1312.0,
#  1313.0,
#  1314.0,
#  1315.0,
#  1317.0,
#  1318.0,
#  1320.0,
#  1321.0,
#  1322.0,
#  1323.0,
#  1324.0,
#  1325.0,
#  1326.0,
#  1327.0,
#  1328.0,
#  1329.0,
#  1330.0,
#  1331.0,
#  1332.0,
#  1333.0,
#  1334.0,
#  1335.0,
#  1336.0,
#  1337.0,
#  1338.0,
#  1339.0,
#  1340.0,
#  1341.0,
#  1342.0,
#  1343.0,
#  1345.0,
#  1346.0,
#  1347.0,
#  1348.0,
#  1349.0,
#  1350.0,
#  1351.0,
#  1352.0,
#  1353.0,
#  1354.0,
#  1355.0,
#  1356.0,
#  1357.0,
#  1358.0,
#  1359.0,
#  1360.0,
#  1361.0,
#  1363.0,
#  1364.0,
#  1365.0,
#  1366.0,
#  1367.0,
#  1368.0,
#  1369.0,
#  1370.0,
#  1371.0,
#  1372.0,
#  1373.0,
#  1374.0,
#  1375.0,
#  1376.0,
#  1377.0,
#  1378.0,
#  1379.0,
#  1380.0,
#  1381.0,
#  1382.0,
#  1383.0,
#  1384.0,
#  1385.0,
#  1386.0,
#  1387.0,
#  1388.0,
#  1389.0,
#  1390.0,
#  1391.0,
#  1393.0,
#  1394.0,
#  1395.0,
#  1396.0,
#  1397.0,
#  1398.0,
#  1399.0,
#  1401.0,
#  1403.0]

# %%
area_ids
# Out:
# {2.0,
#  6.0,
#  15.0,
#  16.0,
#  17.0,
#  22.0,
#  24.0,
#  25.0,
#  34.0,
#  49.0,
#  50.0,
#  51.0,
#  52.0,
#  58.0,
#  61.0,
#  62.0,
#  67.0,
#  68.0,
#  72.0,
#  79.0,
#  83.0,
#  85.0,
#  87.0,
#  89.0,
#  91.0,
#  92.0,
#  95.0,
#  97.0,
#  104.0,
#  105.0,
#  112.0,
#  115.0,
#  117.0,
#  118.0,
#  119.0,
#  120.0,
#  122.0,
#  128.0,
#  130.0,
#  133.0,
#  136.0,
#  137.0,
#  138.0,
#  141.0,
#  142.0,
#  143.0,
#  145.0,
#  147.0,
#  149.0,
#  150.0,
#  151.0,
#  156.0,
#  157.0,
#  160.0,
#  167.0,
#  168.0,
#  171.0,
#  172.0,
#  173.0,
#  174.0,
#  176.0,
#  177.0,
#  178.0,
#  181.0,
#  182.0,
#  184.0,
#  185.0,
#  186.0,
#  187.0,
#  190.0,
#  192.0,
#  195.0,
#  197.0,
#  200.0,
#  201.0,
#  203.0,
#  206.0,
#  207.0,
#  209.0,
#  211.0,
#  212.0,
#  213.0,
#  214.0,
#  215.0,
#  216.0,
#  217.0,
#  218.0,
#  219.0,
#  220.0,
#  221.0,
#  222.0,
#  227.0,
#  235.0,
#  238.0,
#  243.0,
#  253.0,
#  262.0,
#  264.0,
#  269.0,
#  271.0,
#  273.0,
#  278.0,
#  292.0,
#  293.0,
#  296.0,
#  297.0,
#  300.0,
#  301.0,
#  308.0,
#  321.0,
#  326.0,
#  328.0,
#  330.0,
#  334.0,
#  339.0,
#  344.0,
#  352.0,
#  353.0,
#  355.0,
#  356.0,
#  357.0,
#  358.0,
#  362.0,
#  363.0,
#  367.0,
#  369.0,
#  373.0,
#  376.0,
#  384.0,
#  391.0,
#  392.0,
#  393.0,
#  396.0,
#  398.0,
#  404.0,
#  409.0,
#  410.0,
#  413.0,
#  414.0,
#  417.0,
#  418.0,
#  419.0,
#  420.0,
#  422.0,
#  424.0,
#  428.0,
#  432.0,
#  433.0,
#  447.0,
#  448.0,
#  450.0,
#  451.0,
#  452.0,
#  455.0,
#  458.0,
#  463.0,
#  466.0,
#  467.0,
#  471.0,
#  478.0,
#  479.0,
#  483.0,
#  484.0,
#  488.0,
#  492.0,
#  496.0,
#  499.0,
#  502.0,
#  505.0,
#  515.0,
#  516.0,
#  520.0,
#  525.0,
#  529.0,
#  531.0,
#  540.0,
#  541.0,
#  542.0,
#  548.0,
#  549.0,
#  559.0,
#  561.0,
#  567.0,
#  570.0,
#  571.0,
#  572.0,
#  575.0,
#  580.0,
#  585.0,
#  590.0,
#  592.0,
#  595.0,
#  598.0,
#  601.0,
#  603.0,
#  609.0,
#  611.0,
#  625.0,
#  626.0,
#  630.0,
#  637.0,
#  644.0,
#  647.0,
#  663.0,
#  667.0,
#  677.0,
#  679.0,
#  681.0,
#  683.0,
#  689.0,
#  691.0,
#  692.0,
#  693.0,
#  708.0,
#  722.0,
#  726.0,
#  727.0,
#  730.0,
#  731.0,
#  733.0,
#  750.0,
#  758.0,
#  763.0,
#  766.0,
#  767.0,
#  768.0,
#  770.0,
#  776.0,
#  784.0,
#  788.0,
#  789.0,
#  791.0,
#  793.0,
#  798.0,
#  802.0,
#  807.0,
#  814.0,
#  817.0,
#  822.0,
#  824.0,
#  830.0,
#  832.0,
#  833.0,
#  836.0,
#  839.0,
#  845.0,
#  846.0,
#  849.0,
#  852.0,
#  869.0,
#  871.0,
#  873.0,
#  877.0,
#  888.0,
#  901.0,
#  902.0,
#  905.0,
#  912.0,
#  921.0,
#  934.0,
#  936.0,
#  945.0,
#  949.0,
#  953.0,
#  963.0,
#  968.0,
#  974.0,
#  977.0,
#  980.0,
#  987.0,
#  988.0,
#  990.0,
#  994.0,
#  995.0,
#  1004.0,
#  1005.0,
#  1008.0,
#  1010.0,
#  1012.0,
#  1013.0,
#  1014.0,
#  1015.0,
#  1017.0,
#  1021.0,
#  1025.0,
#  1026.0,
#  1032.0,
#  1033.0,
#  1034.0,
#  1036.0,
#  1037.0,
#  1038.0,
#  1039.0,
#  1040.0,
#  1041.0,
#  1042.0,
#  1043.0,
#  1044.0,
#  1045.0,
#  1046.0,
#  1049.0,
#  1052.0,
#  1053.0,
#  1054.0,
#  1056.0,
#  1057.0,
#  1058.0,
#  1059.0,
#  1060.0,
#  1061.0,
#  1062.0,
#  1063.0,
#  1064.0,
#  1065.0,
#  1066.0,
#  1067.0,
#  1068.0,
#  1069.0,
#  1070.0,
#  1071.0,
#  1072.0,
#  1074.0,
#  1075.0,
#  1076.0,
#  1077.0,
#  1078.0,
#  1079.0,
#  1080.0,
#  1081.0,
#  1082.0,
#  1083.0,
#  1084.0,
#  1085.0,
#  1086.0,
#  1087.0,
#  1089.0,
#  1090.0,
#  1091.0,
#  1092.0,
#  1094.0,
#  1095.0,
#  1096.0,
#  1097.0,
#  1098.0,
#  1099.0,
#  1100.0,
#  1101.0,
#  1102.0,
#  1103.0,
#  1106.0,
#  1107.0,
#  1108.0,
#  1109.0,
#  1110.0,
#  1111.0,
#  1112.0,
#  1113.0,
#  1114.0,
#  1117.0,
#  1118.0,
#  1119.0,
#  1120.0,
#  1121.0,
#  1122.0,
#  1123.0,
#  1124.0,
#  1125.0,
#  1126.0,
#  1127.0,
#  1129.0,
#  1130.0,
#  1133.0,
#  1135.0,
#  1136.0,
#  1141.0,
#  1142.0,
#  1143.0,
#  1145.0,
#  1147.0,
#  1148.0,
#  1149.0,
#  1150.0,
#  1152.0,
#  1153.0,
#  1154.0,
#  1155.0,
#  1156.0,
#  1157.0,
#  1158.0,
#  1159.0,
#  1160.0,
#  1161.0,
#  1163.0,
#  1164.0,
#  1165.0,
#  1166.0,
#  1167.0,
#  1168.0,
#  1169.0,
#  1170.0,
#  1171.0,
#  1173.0,
#  1174.0,
#  1175.0,
#  1178.0,
#  1180.0,
#  1181.0,
#  1182.0,
#  1183.0,
#  1184.0,
#  1185.0,
#  1186.0,
#  1189.0,
#  1190.0,
#  1191.0,
#  1192.0,
#  1193.0,
#  1194.0,
#  1195.0,
#  1196.0,
#  1197.0,
#  1198.0,
#  1199.0,
#  1200.0,
#  1201.0,
#  1204.0,
#  1205.0,
#  1206.0,
#  1207.0,
#  1208.0,
#  1209.0,
#  1213.0,
#  1214.0,
#  1215.0,
#  1216.0,
#  1217.0,
#  1218.0,
#  1220.0,
#  1222.0,
#  1223.0,
#  1224.0,
#  1225.0,
#  1226.0,
#  1228.0,
#  1229.0,
#  1230.0,
#  1232.0,
#  1233.0,
#  1234.0,
#  1235.0,
#  1237.0,
#  1238.0,
#  1239.0,
#  1240.0,
#  1242.0,
#  1243.0,
#  1244.0,
#  1245.0,
#  1246.0,
#  1247.0,
#  1248.0,
#  1249.0,
#  1250.0,
#  1252.0,
#  1253.0,
#  1254.0,
#  1255.0,
#  1257.0,
#  1258.0,
#  1259.0,
#  1260.0,
#  1261.0,
#  1262.0,
#  1263.0,
#  1264.0,
#  1265.0,
#  1266.0,
#  1267.0,
#  1268.0,
#  1269.0,
#  1270.0,
#  1271.0,
#  1272.0,
#  1273.0,
#  1274.0,
#  1275.0,
#  1276.0,
#  1277.0,
#  1278.0,
#  1279.0,
#  1280.0,
#  1281.0,
#  1282.0,
#  1283.0,
#  1284.0,
#  1285.0,
#  1286.0,
#  1287.0,
#  1288.0,
#  1289.0,
#  1290.0,
#  1291.0,
#  1292.0,
#  1293.0,
#  1294.0,
#  1295.0,
#  1296.0,
#  1297.0,
#  1298.0,
#  1299.0,
#  1300.0,
#  1301.0,
#  1302.0,
#  1303.0,
#  1304.0,
#  1305.0,
#  1306.0,
#  1307.0,
#  1308.0,
#  1309.0,
#  1310.0,
#  1311.0,
#  1312.0,
#  1313.0,
#  1314.0,
#  1315.0,
#  1317.0,
#  1318.0,
#  1320.0,
#  1321.0,
#  1322.0,
#  1323.0,
#  1324.0,
#  1325.0,
#  1326.0,
#  1327.0,
#  1328.0,
#  1329.0,
#  1330.0,
#  1331.0,
#  1332.0,
#  1333.0,
#  1334.0,
#  1335.0,
#  1336.0,
#  1337.0,
#  1338.0,
#  1339.0,
#  1340.0,
#  1341.0,
#  1342.0,
#  1343.0,
#  1345.0,
#  1346.0,
#  1347.0,
#  1348.0,
#  1349.0,
#  1350.0,
#  1351.0,
#  1352.0,
#  1353.0,
#  1354.0,
#  1355.0,
#  1356.0,
#  1357.0,
#  1358.0,
#  1359.0,
#  1360.0,
#  1361.0,
#  1363.0,
#  1364.0,
#  1365.0,
#  1366.0,
#  1367.0,
#  1368.0,
#  1369.0,
#  1370.0,
#  1371.0,
#  1372.0,
#  1373.0,
#  1374.0,
#  1375.0,
#  1376.0,
#  1377.0,
#  1378.0,
#  1379.0,
#  1380.0,
#  1381.0,
#  1382.0,
#  1383.0,
#  1384.0,
#  1385.0,
#  1386.0,
#  1387.0,
#  1388.0,
#  1389.0,
#  1390.0,
#  1391.0,
#  1393.0,
#  1394.0,
#  1395.0,
#  1396.0,
#  1397.0,
#  1398.0,
#  1399.0,
#  1401.0,
#  1403.0}

# %% [markdown]
# Like we did with area_id, we could similarly also use  city_id for the analysis part

# %%
# visualizing the number of null values for each feature which can be used for cleaning and knowing amount of useable 
# data and useable features 

print("Number of nan values = {}".format(df.isnull().sum()))
# Out:
# Number of nan values = id                         0
# user_id                    0
# vehicle_model_id           0
# package_id             35881
# travel_type_id             0
# from_area_id              88
# to_area_id              9138
# from_city_id           27086
# to_city_id             41843
# from_date                  0
# to_date                17890
# online_booking             0
# mobile_site_booking        0
# booking_created            0
# from_lat                  93
# from_long                 93
# to_lat                  9138
# to_long                 9138
# Car_Cancellation           0
# dtype: int64

# %% [markdown]
# As we see above, some important features like "from_area_id", "to_area_id", "from_lat", "to_lat", "from_long", "to_long" has huge number of NaN values, so we will be cleaning and discarding the rows which have a NaN value for any of these features

# %% [markdown]
# "to_date" feature values can be fixed based on "from_date" and "trip_distance" which can be found from the "from_lat_long" and "to_lat_long" values.

# %%
# remove rows where lat long values are NaN

clean_df = df
clean_df['from_lat'] = df['from_lat'].dropna()

# drop values with string as 'nan'
clean_df = df[ df['from_lat'].astype(str) != 'nan']
clean_df = df[ df['to_lat'].astype(str) != 'nan']

clean_df.isnull().sum()
# Out:
# id                         0
# user_id                    0
# vehicle_model_id           0
# package_id             34293
# travel_type_id             0
# from_area_id               0
# to_area_id                 0
# from_city_id           19788
# to_city_id             34293
# from_date                  0
# to_date                15186
# online_booking             0
# mobile_site_booking        0
# booking_created            0
# from_lat                   0
# from_long                  0
# to_lat                     0
# to_long                    0
# Car_Cancellation           0
# dtype: int64

# %%
df.shape
# Out:
# (43431, 19)

# %%
#tried reindex but gaves nans on missing rows

clean_df = clean_df.reset_index()

# %%
clean_df.head(10)
# Out:
#    index      id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0      0  132512    22177                28         NaN               2
# 1      1  132513    21413                12         NaN               2
# 2      2  132514    22178                12         NaN               2
# 3      3  132515    13034                12         NaN               2
# 4      4  132517    22180                12         NaN               2
# 5      5  132518    17712                12         NaN               2
# 6      7  132520    22181                12         NaN               2
# 7      9  132522    22184                12         NaN               2
# 8     10  132523     4941                12         NaN               2
# 9     11  132524    17037                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id       from_date to_date  \
# 0          83.0       448.0           NaN         NaN   1/1/2013 2:00     NaN
# 1        1010.0       540.0           NaN         NaN   1/1/2013 9:00     NaN
# 2        1301.0      1034.0           NaN         NaN   1/1/2013 3:30     NaN
# 3         768.0       398.0           NaN         NaN   1/1/2013 5:45     NaN
# 4        1365.0       849.0           NaN         NaN   1/1/2013 9:00     NaN
# 5        1021.0      1323.0           NaN         NaN  1/1/2013 22:30     NaN
# 6        1192.0       832.0           NaN         NaN  1/1/2013 11:00     NaN
# 7         516.0       376.0           NaN         NaN  1/1/2013 11:00     NaN
# 8         150.0       776.0           NaN         NaN  1/1/2013 11:00     NaN
# 9         455.0      1330.0           NaN         NaN  1/1/2013 12:45     NaN
#
#    online_booking  mobile_site_booking booking_created   from_lat  from_long  \
# 0               0                    0   1/1/2013 1:39  12.924150  77.672290
# 1               0                    0   1/1/2013 2:25  12.966910  77.749350
# 2               0                    0   1/1/2013 3:08  12.937222  77.626915
# 3               0                    0   1/1/2013 4:39  12.989990  77.553320
# 4               0                    0   1/1/2013 7:53  12.845653  77.677925
# 5               0                    0   1/1/2013 8:01  13.028530  77.546250
# 6               0                    0   1/1/2013 9:39  12.976770  77.572700
# 7               0                    0   1/1/2013 9:49  13.005600  77.657990
# 8               0                    0   1/1/2013 9:55  12.897240  77.610650
# 9               0                    0   1/1/2013 9:59  12.999874  77.678120
#
#       to_lat    to_long  Car_Cancellation
# 0  12.927320  77.635750                 0
# 1  12.927680  77.626640                 0
# 2  13.047926  77.597766                 0
# 3  12.971430  77.639140                 0
# 4  12.954340  77.600720                 0
# 5  12.869805  77.653211                 0
# 6  12.880190  77.645580                 0
# 7  12.902450  77.660810                 0
# 8  13.015080  77.677960                 0
# 9  12.953434  77.706510                 0

# %% [markdown]
# The data is now free from nan values.

# %% [markdown]
# Let us start with univariate analysis

# %%
clean_df['Car_Cancellation'].value_counts(normalize=True).plot.bar(figsize=(8,6), title= 'Cancellation')

# %% [markdown]
# we see that around 7-8% rides get cancelled

# %% [markdown]
# Location Points Visualization

# %%
# m = folium.Map(location = [12.9716, 77.5946], tiles = "Open Street Map")

# for i in range(len(clean_df)):
#     assert clean_df['from_lat'][i] != 0
#     folium.Marker([clean_df['from_lat'][i], clean_df['from_long'][i]]).add_to(m)
# m

# %%
clean_df['from_area_id'].value_counts(sort=False).plot.bar(figsize=(8,6), title= 'pickup area ids')

# %% [markdown]
# ##### ignore the above

# %%
df['from_area_id'].value_counts().head(10)
# Out:
# 393.0     3858
# 571.0     1631
# 293.0     1052
# 585.0      911
# 1010.0     768
# 142.0      727
# 83.0       719
# 1384.0     628
# 1096.0     542
# 58.0       466
# Name: from_area_id, dtype: int64

# %% [markdown]
# These are the top pickup locations based on frequency of pickups

# %%
df['to_area_id'].value_counts().head(10)
# Out:
# 393.0     8777
# 585.0     2339
# 1384.0    1237
# 571.0      664
# 293.0      555
# 1010.0     480
# 83.0       365
# 168.0      338
# 1371.0     332
# 452.0      330
# Name: to_area_id, dtype: int64

# %% [markdown]
# These are the top drop locations based on frequency of drops

# %%
df['travel_type_id'].value_counts(sort=False).plot(kind='bar')

# %% [markdown]
# The most used travel type is point to point, so we say that point -to - point is the main thing that gets revenue to the company while hourly rental is rare but may get good revenue and less expense.

# %% [markdown]
# ##### I removed travel type3 bymistake bcoz they didn't have 'from_lat' and 'from_long'
# ###### travel3 is hourly service so it did not have lat long values

# %%
df.head()
# Out:
#        id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0  132512    22177                28         NaN               2
# 1  132513    21413                12         NaN               2
# 2  132514    22178                12         NaN               2
# 3  132515    13034                12         NaN               2
# 4  132517    22180                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id      from_date to_date  \
# 0          83.0       448.0           NaN         NaN  1/1/2013 2:00     NaN
# 1        1010.0       540.0           NaN         NaN  1/1/2013 9:00     NaN
# 2        1301.0      1034.0           NaN         NaN  1/1/2013 3:30     NaN
# 3         768.0       398.0           NaN         NaN  1/1/2013 5:45     NaN
# 4        1365.0       849.0           NaN         NaN  1/1/2013 9:00     NaN
#
#    online_booking  mobile_site_booking booking_created   from_lat  from_long  \
# 0               0                    0   1/1/2013 1:39  12.924150  77.672290
# 1               0                    0   1/1/2013 2:25  12.966910  77.749350
# 2               0                    0   1/1/2013 3:08  12.937222  77.626915
# 3               0                    0   1/1/2013 4:39  12.989990  77.553320
# 4               0                    0   1/1/2013 7:53  12.845653  77.677925
#
#       to_lat    to_long  Car_Cancellation
# 0  12.927320  77.635750                 0
# 1  12.927680  77.626640                 0
# 2  13.047926  77.597766                 0
# 3  12.971430  77.639140                 0
# 4  12.954340  77.600720                 0

# %%
df['from_date'].dtype
# Out:
# dtype('O')

# %%
df['from_date'] = pd.to_datetime(df['from_date'],format='%m/%d/%Y %H:%M')

# %%
df.index = df.index.sort_values()
df.head()
# Out:
#        id  user_id  vehicle_model_id  package_id  travel_type_id  \
# 0  132512    22177                28         NaN               2
# 1  132513    21413                12         NaN               2
# 2  132514    22178                12         NaN               2
# 3  132515    13034                12         NaN               2
# 4  132517    22180                12         NaN               2
#
#    from_area_id  to_area_id  from_city_id  to_city_id           from_date  \
# 0          83.0       448.0           NaN         NaN 2013-01-01 02:00:00
# 1        1010.0       540.0           NaN         NaN 2013-01-01 09:00:00
# 2        1301.0      1034.0           NaN         NaN 2013-01-01 03:30:00
# 3         768.0       398.0           NaN         NaN 2013-01-01 05:45:00
# 4        1365.0       849.0           NaN         NaN 2013-01-01 09:00:00
#
#   to_date  online_booking  mobile_site_booking booking_created   from_lat  \
# 0     NaN               0                    0   1/1/2013 1:39  12.924150
# 1     NaN               0                    0   1/1/2013 2:25  12.966910
# 2     NaN               0                    0   1/1/2013 3:08  12.937222
# 3     NaN               0                    0   1/1/2013 4:39  12.989990
# 4     NaN               0                    0   1/1/2013 7:53  12.845653
#
#    from_long     to_lat    to_long  Car_Cancellation
# 0  77.672290  12.927320  77.635750                 0
# 1  77.749350  12.927680  77.626640                 0
# 2  77.626915  13.047926  77.597766                 0
# 3  77.553320  12.971430  77.639140                 0
# 4  77.677925  12.954340  77.600720                 0

# %%
df.index = df['from_date']
df.head()
# Out:
#                          id  user_id  vehicle_model_id  package_id  \
# from_date
# 2013-01-01 02:00:00  132512    22177                28         NaN
# 2013-01-01 09:00:00  132513    21413                12         NaN
# 2013-01-01 03:30:00  132514    22178                12         NaN
# 2013-01-01 05:45:00  132515    13034                12         NaN
# 2013-01-01 09:00:00  132517    22180                12         NaN
#
#                      travel_type_id  from_area_id  to_area_id  from_city_id  \
# from_date
# 2013-01-01 02:00:00               2          83.0       448.0           NaN
# 2013-01-01 09:00:00               2        1010.0       540.0           NaN
# 2013-01-01 03:30:00               2        1301.0      1034.0           NaN
# 2013-01-01 05:45:00               2         768.0       398.0           NaN
# 2013-01-01 09:00:00               2        1365.0       849.0           NaN
#
#                      to_city_id           from_date to_date  online_booking  \
# from_date
# 2013-01-01 02:00:00         NaN 2013-01-01 02:00:00     NaN               0
# 2013-01-01 09:00:00         NaN 2013-01-01 09:00:00     NaN               0
# 2013-01-01 03:30:00         NaN 2013-01-01 03:30:00     NaN               0
# 2013-01-01 05:45:00         NaN 2013-01-01 05:45:00     NaN               0
# 2013-01-01 09:00:00         NaN 2013-01-01 09:00:00     NaN               0
#
#                      mobile_site_booking booking_created   from_lat  \
# from_date
# 2013-01-01 02:00:00                    0   1/1/2013 1:39  12.924150
# 2013-01-01 09:00:00                    0   1/1/2013 2:25  12.966910
# 2013-01-01 03:30:00                    0   1/1/2013 3:08  12.937222
# 2013-01-01 05:45:00                    0   1/1/2013 4:39  12.989990
# 2013-01-01 09:00:00                    0   1/1/2013 7:53  12.845653
#
#                      from_long     to_lat    to_long  Car_Cancellation
# from_date
# 2013-01-01 02:00:00  77.672290  12.927320  77.635750                 0
# 2013-01-01 09:00:00  77.749350  12.927680  77.626640                 0
# 2013-01-01 03:30:00  77.626915  13.047926  77.597766                 0
# 2013-01-01 05:45:00  77.553320  12.971430  77.639140                 0
# 2013-01-01 09:00:00  77.677925  12.954340  77.600720                 0

# %%
df['from_year'] = df['from_date'].dt.year
df['from_month'] = df['from_date'].dt.month 
df['from_day'] = df['from_date'].dt.day
df['from_hour'] = df['from_date'].dt.hour
df['from_day_of_week'] = df['from_date'].dt.dayofweek

# %%
df.head()
# Out:
#                          id  user_id  vehicle_model_id  package_id  \
# from_date
# 2013-01-01 02:00:00  132512    22177                28         NaN
# 2013-01-01 09:00:00  132513    21413                12         NaN
# 2013-01-01 03:30:00  132514    22178                12         NaN
# 2013-01-01 05:45:00  132515    13034                12         NaN
# 2013-01-01 09:00:00  132517    22180                12         NaN
#
#                      travel_type_id  from_area_id  to_area_id  from_city_id  \
# from_date
# 2013-01-01 02:00:00               2          83.0       448.0           NaN
# 2013-01-01 09:00:00               2        1010.0       540.0           NaN
# 2013-01-01 03:30:00               2        1301.0      1034.0           NaN
# 2013-01-01 05:45:00               2         768.0       398.0           NaN
# 2013-01-01 09:00:00               2        1365.0       849.0           NaN
#
#                      to_city_id           from_date    ...      \
# from_date                                              ...
# 2013-01-01 02:00:00         NaN 2013-01-01 02:00:00    ...
# 2013-01-01 09:00:00         NaN 2013-01-01 09:00:00    ...
# 2013-01-01 03:30:00         NaN 2013-01-01 03:30:00    ...
# 2013-01-01 05:45:00         NaN 2013-01-01 05:45:00    ...
# 2013-01-01 09:00:00         NaN 2013-01-01 09:00:00    ...
#
#                     booking_created   from_lat  from_long     to_lat  \
# from_date
# 2013-01-01 02:00:00   1/1/2013 1:39  12.924150  77.672290  12.927320
# 2013-01-01 09:00:00   1/1/2013 2:25  12.966910  77.749350  12.927680
# 2013-01-01 03:30:00   1/1/2013 3:08  12.937222  77.626915  13.047926
# 2013-01-01 05:45:00   1/1/2013 4:39  12.989990  77.553320  12.971430
# 2013-01-01 09:00:00   1/1/2013 7:53  12.845653  77.677925  12.954340
#
#                        to_long  Car_Cancellation  from_year  from_month  \
# from_date
# 2013-01-01 02:00:00  77.635750                 0       2013           1
# 2013-01-01 09:00:00  77.626640                 0       2013           1
# 2013-01-01 03:30:00  77.597766                 0       2013           1
# 2013-01-01 05:45:00  77.639140                 0       2013           1
# 2013-01-01 09:00:00  77.600720                 0       2013           1
#
#                      from_day  from_hour
# from_date
# 2013-01-01 02:00:00         1          2
# 2013-01-01 09:00:00         1          9
# 2013-01-01 03:30:00         1          3
# 2013-01-01 05:45:00         1          5
# 2013-01-01 09:00:00         1          9
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#                          id  user_id  vehicle_model_id  package_id  \
# from_date
# 2013-11-24 18:00:00  185937    14364                12         NaN
# 2013-11-26 01:00:00  185938    48727                12         NaN
# 2013-11-24 18:30:00  185939    48729                12         1.0
# 2013-11-24 16:00:00  185940    30724                87         NaN
# 2013-11-25 05:00:00  185941    48730                12         NaN
#
#                      travel_type_id  from_area_id  to_area_id  from_city_id  \
# from_date
# 2013-11-24 18:00:00               2        1147.0       452.0          15.0
# 2013-11-26 01:00:00               2         393.0       466.0          15.0
# 2013-11-24 18:30:00               3         974.0         NaN          15.0
# 2013-11-24 16:00:00               2        1263.0       542.0          15.0
# 2013-11-25 05:00:00               2         689.0       393.0          15.0
#
#                      to_city_id           from_date    ...      \
# from_date                                              ...
# 2013-11-24 18:00:00         NaN 2013-11-24 18:00:00    ...
# 2013-11-26 01:00:00         NaN 2013-11-26 01:00:00    ...
# 2013-11-24 18:30:00         NaN 2013-11-24 18:30:00    ...
# 2013-11-24 16:00:00         NaN 2013-11-24 16:00:00    ...
# 2013-11-25 05:00:00         NaN 2013-11-25 05:00:00    ...
#
#                       booking_created  from_lat  from_long     to_lat  \
# from_date
# 2013-11-24 18:00:00  11/24/2013 14:25  13.03064   77.64910  12.952780
# 2013-11-26 01:00:00  11/24/2013 14:30  13.19956   77.70688  13.017436
# 2013-11-24 18:30:00  11/24/2013 14:35  13.07557   77.55904        NaN
# 2013-11-24 16:00:00  11/24/2013 14:43  12.96897   77.59456  12.938230
# 2013-11-25 05:00:00  11/24/2013 14:50  12.97672   77.64927  13.199560
#
#                       to_long  Car_Cancellation  from_year  from_month  \
# from_date
# 2013-11-24 18:00:00  77.59088                 0       2013          11
# 2013-11-26 01:00:00  77.64458                 0       2013          11
# 2013-11-24 18:30:00       NaN                 0       2013          11
# 2013-11-24 16:00:00  77.62289                 0       2013          11
# 2013-11-25 05:00:00  77.70688                 0       2013          11
#
#                      from_day  from_hour
# from_date
# 2013-11-24 18:00:00        24         18
# 2013-11-26 01:00:00        26          1
# 2013-11-24 18:30:00        24         18
# 2013-11-24 16:00:00        24         16
# 2013-11-25 05:00:00        25          5
#
# [5 rows x 23 columns]

# %% [markdown]
# Time based analysis

# %%
df['from_day'].value_counts(sort=False).plot.bar()

# %% [markdown]
# we can see here that the demand for taxi fluctuates throughout the month with small peaks in between, but this can't be used for concluding anything relevant

# %%
df['from_month'].value_counts(sort=False).plot.bar()

# %% [markdown]
# There is more demand for the taxis from month of may to october(possibly bcoz of hot summers, summer vacations and rainy season later) with heighest in august, so more revenue should be generated during those periods

# %%
df['from_year'].value_counts(sort=False).plot.bar()

# %% [markdown]
# Not a useful visualization since we have only 1 years' data

# %%
df['from_hour'].value_counts(sort=False).plot.bar()

# %% [markdown]
# Here we see the hourly demand fluctuations, there is a really decent demand after midnight, peak demands are during 6-10 am and then 4-7pm and average demands otherwise

# %% [markdown]
# check if weekday or weekend

# %%
def weekend(day):
    weekend = 0
    if day == 5 | day == 6:
        weekend = 1
    return weekend

# %%
df['weekend'] = df['from_day_of_week'].apply(lambda s:weekend(s))

# %%
df.head()
# Out:
#                          id  user_id  vehicle_model_id  package_id  \
# from_date
# 2013-01-01 02:00:00  132512    22177                28         NaN
# 2013-01-01 09:00:00  132513    21413                12         NaN
# 2013-01-01 03:30:00  132514    22178                12         NaN
# 2013-01-01 05:45:00  132515    13034                12         NaN
# 2013-01-01 09:00:00  132517    22180                12         NaN
#
#                      travel_type_id  from_area_id  to_area_id  from_city_id  \
# from_date
# 2013-01-01 02:00:00               2          83.0       448.0           NaN
# 2013-01-01 09:00:00               2        1010.0       540.0           NaN
# 2013-01-01 03:30:00               2        1301.0      1034.0           NaN
# 2013-01-01 05:45:00               2         768.0       398.0           NaN
# 2013-01-01 09:00:00               2        1365.0       849.0           NaN
#
#                      to_city_id           from_date   ...     from_long  \
# from_date                                             ...
# 2013-01-01 02:00:00         NaN 2013-01-01 02:00:00   ...     77.672290
# 2013-01-01 09:00:00         NaN 2013-01-01 09:00:00   ...     77.749350
# 2013-01-01 03:30:00         NaN 2013-01-01 03:30:00   ...     77.626915
# 2013-01-01 05:45:00         NaN 2013-01-01 05:45:00   ...     77.553320
# 2013-01-01 09:00:00         NaN 2013-01-01 09:00:00   ...     77.677925
#
#                         to_lat    to_long Car_Cancellation  from_year  \
# from_date
# 2013-01-01 02:00:00  12.927320  77.635750                0       2013
# 2013-01-01 09:00:00  12.927680  77.626640                0       2013
# 2013-01-01 03:30:00  13.047926  77.597766                0       2013
# 2013-01-01 05:45:00  12.971430  77.639140                0       2013
# 2013-01-01 09:00:00  12.954340  77.600720                0       2013
#
#                      from_month  from_day  from_hour  from_day_of_week  \
# from_date
# 2013-01-01 02:00:00           1         1          2                 1
# 2013-01-01 09:00:00           1         1          9                 1
# 2013-01-01 03:30:00           1         1          3                 1
# 2013-01-01 05:45:00           1         1          5                 1
# 2013-01-01 09:00:00           1         1          9                 1
#
#                      weekend
# from_date
# 2013-01-01 02:00:00        0
# 2013-01-01 09:00:00        0
# 2013-01-01 03:30:00        0
# 2013-01-01 05:45:00        0
# 2013-01-01 09:00:00        0
#
# [5 rows x 25 columns]

# %%
df['from_day_of_week'].value_counts(sort=False).plot.bar()

# %% [markdown]
# We see that Fridays and Saturdays have a slightly higher demand than other days

# %% [markdown]
# ##### Strategy based on demand which we discovered through visualising the data
#
# - Extra charge during night time
# - Extra charge during peak timings and high demands timings
# - No offers during peak timings and high demand timings , otherwise offers can be offered to get more people using the service

# %% [markdown]
# Now for deciding that what areas should the taxis made available at what times, first we will have to calculate no. of "Drives" at particular times in particular areas
#
# We will get area_wise data and visualize it w.r.t the time

# %%
df_area1 = df[df['from_area_id']==2]

# %%
df_area1['from_hour'].value_counts(sort=False).plot.bar()

# %%
df_area2 = df[df['from_area_id']==6]

# %%
df_area2
# Out:
#                          id  user_id  vehicle_model_id  package_id  \
# from_date
# 2013-01-02 16:00:00  132632      694                28         2.0
# 2013-01-12 06:00:00  133538      743                12         NaN
# 2013-03-14 14:30:00  141100    33406                12         NaN
# 2013-06-29 11:45:00  157461    22027                12         NaN
# 2013-07-03 21:30:00  158202      743                12         NaN
# 2013-07-22 12:45:00  161820    37177                12         NaN
# 2013-09-06 08:15:00  171779    41719                90         NaN
#
#                      travel_type_id  from_area_id  to_area_id  from_city_id  \
# from_date
# 2013-01-02 16:00:00               3           6.0         NaN           NaN
# 2013-01-12 06:00:00               2           6.0       393.0           NaN
# 2013-03-14 14:30:00               2           6.0       448.0           NaN
# 2013-06-29 11:45:00               2           6.0       515.0           NaN
# 2013-07-03 21:30:00               2           6.0       585.0           NaN
# 2013-07-22 12:45:00               2           6.0       393.0           NaN
# 2013-09-06 08:15:00               2           6.0       393.0          15.0
#
#                      to_city_id           from_date   ...    from_long  \
# from_date                                             ...
# 2013-01-02 16:00:00         NaN 2013-01-02 16:00:00   ...     77.61762
# 2013-01-12 06:00:00         NaN 2013-01-12 06:00:00   ...     77.61762
# 2013-03-14 14:30:00         NaN 2013-03-14 14:30:00   ...     77.61762
# 2013-06-29 11:45:00         NaN 2013-06-29 11:45:00   ...     77.61762
# 2013-07-03 21:30:00         NaN 2013-07-03 21:30:00   ...     77.61762
# 2013-07-22 12:45:00         NaN 2013-07-22 12:45:00   ...     77.61762
# 2013-09-06 08:15:00         NaN 2013-09-06 08:15:00   ...     77.61762
#
#                        to_lat   to_long Car_Cancellation  from_year  \
# from_date
# 2013-01-02 16:00:00       NaN       NaN                0       2013
# 2013-01-12 06:00:00  13.19956  77.70688                0       2013
# 2013-03-14 14:30:00  12.92732  77.63575                0       2013
# 2013-06-29 11:45:00  12.97896  77.67345                0       2013
# 2013-07-03 21:30:00  12.97677  77.57270                0       2013
# 2013-07-22 12:45:00  13.19956  77.70688                0       2013
# 2013-09-06 08:15:00  13.19956  77.70688                0       2013
#
#                      from_month  from_day  from_hour  from_day_of_week  \
# from_date
# 2013-01-02 16:00:00           1         2         16                 2
# 2013-01-12 06:00:00           1        12          6                 5
# 2013-03-14 14:30:00           3        14         14                 3
# 2013-06-29 11:45:00           6        29         11                 5
# 2013-07-03 21:30:00           7         3         21                 2
# 2013-07-22 12:45:00           7        22         12                 0
# 2013-09-06 08:15:00           9         6          8                 4
#
#                      weekend
# from_date
# 2013-01-02 16:00:00        0
# 2013-01-12 06:00:00        0
# 2013-03-14 14:30:00        0
# 2013-06-29 11:45:00        0
# 2013-07-03 21:30:00        0
# 2013-07-22 12:45:00        0
# 2013-09-06 08:15:00        0
#
# [7 rows x 25 columns]

# %%
df_area2['from_hour'].value_counts(sort=False).plot.bar()

# %%
df[df.from_area_id==15]['from_hour'].value_counts(sort=False).plot.bar()

# %% [markdown]
# Average demand from this graphs can be calculated for the particular times

# %% [markdown]
# Now for deciding that what areas should the taxis made available at what times, first we will have to calculate no. of "Drives" at particular times in particular areas
#
# we will have to get data for all 607 areas and apply time series forecasting
#
# Data would look something like this
#
# Area1_00,Area1_01,...Area1_22,Area1_23
# .<br>
# .<br>
# .<br>
# Area607_00,Area607_01...Area607_22,Area607_23
